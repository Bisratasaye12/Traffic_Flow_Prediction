# %%
import pandas as pd

# Load the preprocessed training data
data = pd.read_csv('../data/processed/train.csv')

# %% [markdown]
# ## Histograms of Numerical Features:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(12, 8))

# Create histograms for Avg_Speed, Mileage, and Distance
numerical_features = ['Avg_Speed', 'Mileage', 'Distance']
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 3, i)
    sns.histplot(data[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Boxplots for Numerical Features (Identifying Outliers)

# %%
# Set up the figure
plt.figure(figsize=(12, 8))

# Create boxplots for Avg_Speed, Mileage, and Distance
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data[feature])
    plt.title(f'Boxplot of {feature}')
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Traffic Distribution by Categories

# %%
# Plot traffic distribution based on the TrafficLevel
plt.figure(figsize=(8, 6))
sns.countplot(x='TrafficLevel', data=data)
plt.title('Traffic Level Distribution')
plt.xlabel('Traffic Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
# Calculate the correlation matrix for numerical features
correlation_matrix = data[['Avg_Speed', 'Mileage', 'Distance', 'total_time']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
